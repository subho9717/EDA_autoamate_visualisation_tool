# %%
# !pip install klib
# Out:
# Requirement already satisfied: klib in c:\users\subhajit\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (3.5.1)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (1.9.1)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.1 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (0.11.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (1.21.5)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (1.4.2)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in c:\users\subhajit\anaconda3\lib\site-packages (from klib) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subhajit\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.2.0->klib) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\subhajit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)

# %%
import pandas as pd
data = r"E:\OneDrive - student.amity.edu\office\python & R\DataScience_ineuron\Ineuron tutorial resources\EDA\EDA_Dataset\Dataset\data5\Visadataset.csv"
df = pd.read_csv(data)

# %%
import klib

# %%
klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 9)

# %%
klib.corr_mat(df) # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_00d95_row0_col0, #T_00d95_row1_col1, #T_00d95_row1_col2, #T_00d95_row2_col1, #T_00d95_row2_col2 {
#   color: None;
# }
# #T_00d95_row0_col1, #T_00d95_row0_col2, #T_00d95_row1_col0, #T_00d95_row2_col0 {
#   color: #FF3344;
# }
# </style>
# <table id="T_00d95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d95_level0_col0" class="col_heading level0 col0" >no_of_employees</th>
#       <th id="T_00d95_level0_col1" class="col_heading level0 col1" >yr_of_estab</th>
#       <th id="T_00d95_level0_col2" class="col_heading level0 col2" >prevailing_wage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d95_level0_row0" class="row_heading level0 row0" >no_of_employees</th>
#       <td id="T_00d95_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_00d95_row0_col1" class="data row0 col1" >-0.02</td>
#       <td id="T_00d95_row0_col2" class="data row0 col2" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_00d95_level0_row1" class="row_heading level0 row1" >yr_of_estab</th>
#       <td id="T_00d95_row1_col0" class="data row1 col0" >-0.02</td>
#       <td id="T_00d95_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_00d95_row1_col2" class="data row1 col2" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_00d95_level0_row2" class="row_heading level0 row2" >prevailing_wage</th>
#       <td id="T_00d95_row2_col0" class="data row2 col0" >-0.01</td>
#       <td id="T_00d95_row2_col1" class="data row2 col1" >0.01</td>
#       <td id="T_00d95_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 klib.corr_plot(df)
#
# File ~\anaconda3\lib\site-packages\klib\describe.py:381, in corr_plot(data, split, threshold, target, method, cmap, figsize, annot, dev, **kwargs)
#     368 kwargs = {
#     369     "mask": mask,
#     370     "cmap": cmap,
#    (...)
#     377     **kwargs,
#     378 }
#     380 # Draw heatmap with mask and default settings
# --> 381 sns.heatmap(corr, center=0, fmt=".2f", **kwargs)
#     383 ax.set_title(f"Feature-correlation ({method})", fontdict={"fontsize": 18})
#     385 # Settings
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:159, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     156 self.ylabel = ylabel if ylabel is not None else ""
#     158 # Determine good default values for the colormapping
# --> 159 self._determine_cmap_params(plot_data, vmin, vmax,
#     160                             cmap, center, robust)
#     162 # Sort out the annotations
#     163 if annot is None or annot is False:
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:236, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     234 vrange = max(vmax - center, center - vmin)
#     235 normlize = mpl.colors.Normalize(center - vrange, center + vrange)
# --> 236 cmin, cmax = normlize([vmin, vmax])
#     237 cc = np.linspace(cmin, cmax, 256)
#     238 self.cmap = mpl.colors.ListedColormap(self.cmap(cc))
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:1245, in Normalize.__call__(self, value, clip)
#    1243     result.fill(0)   # Or should it be all masked?  Or 0.5?
#    1244 elif vmin > vmax:
# -> 1245     raise ValueError("minvalue must be less than or equal to maxvalue")
#    1246 else:
#    1247     if clip:
#
# ValueError: minvalue must be less than or equal to maxvalue

# %%
klib.dist_plot(df) # returns a distribution plot for every numeric feature
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='prevailing_wage', ylabel='Density'>

# %%
klib.missingval_plot(df) # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.
