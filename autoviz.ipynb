# %%
# !pip install autoviz==0.0.6
# Out:
# Collecting autoviz==0.0.6
#   Downloading autoviz-0.0.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: matplotlib in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (3.5.1)
# Requirement already satisfied: ipython in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (8.2.0)
# Requirement already satisfied: seaborn in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (0.11.2)
# Requirement already satisfied: jupyter in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (1.0.0)
# Requirement already satisfied: pandas in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\subhajit\anaconda3\lib\site-packages (from autoviz==0.0.6) (1.0.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (2.11.2)
# Requirement already satisfied: decorator in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (60.10.0)
# Requirement already satisfied: backcall in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.1.2)
# Requirement already satisfied: colorama in c:\users\subhajit\anaconda3\lib\site-packages (from ipython->autoviz==0.0.6) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jedi>=0.16->ipython->autoviz==0.0.6) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\subhajit\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz==0.0.6) (0.2.5)
# Requirement already satisfied: qtconsole in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (5.3.0)
# Requirement already satisfied: jupyter-console in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (6.4.0)
# Requirement already satisfied: ipywidgets in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (6.4.4)
# Requirement already satisfied: notebook in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (6.4.8)
# Requirement already satisfied: ipykernel in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter->autoviz==0.0.6) (6.9.1)
# Requirement already satisfied: nest-asyncio in c:\users\subhajit\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz==0.0.6) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz==0.0.6) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\subhajit\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz==0.0.6) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz==0.0.6) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz==0.0.6) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz==0.0.6) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz==0.0.6) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->autoviz==0.0.6) (302)
# Requirement already satisfied: six>=1.5 in c:\users\subhajit\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter->autoviz==0.0.6) (1.16.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz==0.0.6) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz==0.0.6) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz==0.0.6) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\subhajit\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz==0.0.6) (3.0.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\subhajit\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz==0.0.6) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\subhajit\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz==0.0.6) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz==0.0.6) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->autoviz==0.0.6) (0.18.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\subhajit\anaconda3\lib\site-packages (from notebook->jupyter->autoviz==0.0.6) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\subhajit\anaconda3\lib\site-packages (from notebook->jupyter->autoviz==0.0.6) (3.0.3)
# Requirement already satisfied: prometheus-client in c:\users\subhajit\anaconda3\lib\site-packages (from notebook->jupyter->autoviz==0.0.6) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\subhajit\anaconda3\lib\site-packages (from notebook->jupyter->autoviz==0.0.6) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\subhajit\anaconda3\lib\site-packages (from notebook->jupyter->autoviz==0.0.6) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\subhajit\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz==0.0.6) (1.1.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\subhajit\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz==0.0.6) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\subhajit\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz==0.0.6) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\subhajit\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->autoviz==0.0.6) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from jinja2->notebook->jupyter->autoviz==0.0.6) (2.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->autoviz==0.0.6) (0.11.0)
# Requirement already satisfied: bleach in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.1.2)
# Requirement already satisfied: testpath in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\subhajit\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz==0.0.6) (0.8.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\subhajit\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz==0.0.6) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\subhajit\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->autoviz==0.0.6) (0.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subhajit\anaconda3\lib\site-packages (from pandas->autoviz==0.0.6) (2021.3)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\subhajit\anaconda3\lib\site-packages (from qtconsole->jupyter->autoviz==0.0.6) (2.0.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\subhajit\anaconda3\lib\site-packages (from scikit-learn->autoviz==0.0.6) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subhajit\anaconda3\lib\site-packages (from scikit-learn->autoviz==0.0.6) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\subhajit\anaconda3\lib\site-packages (from scikit-learn->autoviz==0.0.6) (1.1.0)
# Requirement already satisfied: asttokens in c:\users\subhajit\anaconda3\lib\site-packages (from stack-data->ipython->autoviz==0.0.6) (2.0.5)
# Requirement already satisfied: executing in c:\users\subhajit\anaconda3\lib\site-packages (from stack-data->ipython->autoviz==0.0.6) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\subhajit\anaconda3\lib\site-packages (from stack-data->ipython->autoviz==0.0.6) (0.2.2)
# Installing collected packages: autoviz
#   Attempting uninstall: autoviz
#     Found existing installation: autoviz 0.1.55
#     Uninstalling autoviz-0.1.55:
#       Successfully uninstalled autoviz-0.1.55
# Successfully installed autoviz-0.0.6

# %%
import pandas as pd
data = r"E:\OneDrive - student.amity.edu\office\python & R\DataScience_ineuron\Ineuron tutorial resources\EDA\EDA_Dataset\Dataset\data5\Visadataset.csv"
df = pd.read_csv(data)

# %%
from autoviz.AutoViz_Class import AutoViz_Class 
AV=AutoViz_Class()
# Out:
# Imported AutoViz_Class. Call by using AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)

# %%
filename = ""
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=df,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="jpg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30
)
# Out:
# Shape of your Data Set: (25480, 12)
# Classifying variables in data set...
#     12 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
# Nothing to add Plot not being added
# Nothing to add Plot not being added
# Could not draw Bar Plots
# Time to run AutoViz (in seconds) = 1.212
