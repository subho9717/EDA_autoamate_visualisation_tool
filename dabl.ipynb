# %%
# !pip install dabl
# Out:
# Collecting dabl
#   Downloading dabl-0.2.2-py3-none-any.whl (558 kB)
# Requirement already satisfied: seaborn in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (0.11.2)
# Requirement already satisfied: scipy in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (3.5.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (1.0.2)
# Requirement already satisfied: pandas in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (1.4.2)
# Requirement already satisfied: numpy in c:\users\subhajit\anaconda3\lib\site-packages (from dabl) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\subhajit\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->dabl) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subhajit\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->dabl) (2.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subhajit\anaconda3\lib\site-packages (from matplotlib->dabl) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\subhajit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dabl) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subhajit\anaconda3\lib\site-packages (from pandas->dabl) (2021.3)
# Installing collected packages: dabl
# Successfully installed dabl-0.2.2

# %%
import pandas as pd
data = r"E:\OneDrive - student.amity.edu\office\python & R\DataScience_ineuron\Ineuron tutorial resources\EDA\EDA_Dataset\Dataset\data5\Visadataset.csv"
df = pd.read_csv(data)
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
import dabl
dabl.plot(df,target_col='case_status')
# Out:
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.500
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Subhajit\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [[<Figure size 648x648 with 12 Axes>,
#   <Figure size 1152x288 with 4 Axes>,
#   <Figure size 432x288 with 1 Axes>],
#  None]
